# %%
import pandas as pd #oh boy, here we go
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
df_171=pd.read_csv('diaries/diary17/fmld171.csv')
df_171['quarter']=1
df_171['year']=2017

df_172=pd.read_csv('diaries/diary17/fmld172.csv')
df_172['quarter']=2
df_172['year']=2017

df_173=pd.read_csv('diaries/diary17/fmld173.csv')
df_173['quarter']=3
df_173['year']=2017

df_174=pd.read_csv('diaries/diary17/fmld174.csv')
df_174['quarter']=4
df_174['year']=2017

df_2017=pd.concat([df_171, df_172, df_173, df_174], ignore_index=True)
df_2017.columns=df_2017.columns.str.lower()
df_181=pd.read_csv('diaries/diary18/fmld181.csv')
df_181['quarter']=1
df_181['year']=2018

df_182=pd.read_csv('diaries/diary18/fmld182.csv')
df_182['quarter']=2
df_182['year']=2018

df_183=pd.read_csv('diaries/diary18/fmld183.csv')
df_183['quarter']=3
df_183['year']=2018

df_184=pd.read_csv('diaries/diary18/fmld184.csv')
df_184['quarter']=4
df_184['year']=2018

df_2018=pd.concat([df_181, df_182, df_183, df_184], ignore_index=True)
df_2018.columns=df_2018.columns.str.lower()
df_191=pd.read_csv('diaries/diary19/fmld191.csv')
df_191['quarter']=1
df_191['year']=2019

df_192=pd.read_csv('diaries/diary19/fmld192.csv')
df_192['quarter']=2
df_192['year']=2019

df_193=pd.read_csv('diaries/diary19/fmld193.csv')
df_193['quarter']=3
df_193['year']=2019

df_194=pd.read_csv('diaries/diary19/fmld194.csv')
df_194['quarter']=4
df_194['year']=2019

df_2019=pd.concat([df_191, df_192, df_193, df_194], ignore_index=True)
df_2019.columns=df_2019.columns.str.lower()
df_201=pd.read_csv('diaries/diary20/fmld201.csv')
df_201['quarter']=1
df_201['year']=2020

df_202=pd.read_csv('diaries/diary20/fmld202.csv')
df_202['quarter']=2
df_202['year']=2020

df_203=pd.read_csv('diaries/diary20/fmld203.csv')
df_203['quarter']=3
df_203['year']=2020

df_204=pd.read_csv('diaries/diary20/fmld204.csv')
df_204['quarter']=4
df_204['year']=2020

df_2020=pd.concat([df_201, df_202, df_203, df_204], ignore_index=True)
df_2020.columns=df_2020.columns.str.lower()
df_211=pd.read_csv('diaries/diary21/fmld211.csv')
df_211['quarter']=1
df_211['year']=2021

df_212=pd.read_csv('diaries/diary21/fmld212.csv')
df_212['quarter']=2
df_212['year']=2021

df_213=pd.read_csv('diaries/diary21/fmld213.csv')
df_213['quarter']=3
df_213['year']=2021

df_214=pd.read_csv('diaries/diary21/fmld214.csv')
df_214['quarter']=4
df_214['year']=2021

df_2021=pd.concat([df_211, df_212, df_213, df_214], ignore_index=True)
df_2021.columns=df_2021.columns.str.lower()
df_221=pd.read_csv('diaries/diary22/fmld221.csv')
df_221['quarter']=1
df_221['year']=2022

df_222=pd.read_csv('diaries/diary22/fmld222.csv')
df_222['quarter']=2
df_222['year']=2022

df_223=pd.read_csv('diaries/diary22/fmld223.csv')
df_223['quarter']=3
df_223['year']=2022

df_224=pd.read_csv('diaries/diary22/fmld224.csv')
df_224['quarter']=4
df_224['year']=2022


df_2022=pd.concat([df_221, df_222, df_223, df_224], ignore_index=True)
df_2022.columns=df_2022.columns.str.lower()
df=pd.concat([df_2017, df_2018, df_2019, df_2020, df_2021, df_2022], ignore_index=True)
df.columns=df.columns.str.lower()

# i wanted to automate this, but it was kind of a pain in the ass

# %%
df.head()
# Out:
#    inc_rnkm  inc_rnk5  inc_rnk4  inc_rnk3  inc_rnk2  inc_rnk1  inc_rank  \
# 0  0.704287  0.706457  0.699513  0.705671  0.709034  0.707517  0.763599
# 1  0.704573  0.706744  0.699800  0.705958  0.709321  0.707804  0.763886
# 2  0.256737  0.272063  0.260261  0.263508  0.273057  0.266441  0.375717
# 3  0.256312  0.271638  0.259836  0.263083  0.272632  0.266016  0.375292
# 4  0.346813  0.360343  0.345145  0.350655  0.364780  0.354823  0.458908
#
#      newid  age_ref age_ref_  ...  othr_gxm rets_rvm  roye_txm  division  \
# 0  3608891       27        D  ...         A        A         A       8.0
# 1  3608892       27        D  ...         A        A         A       8.0
# 2  3608901       53        D  ...         A        A         A       4.0
# 3  3608902       53        D  ...         A        A         A       4.0
# 4  3608921       56        D  ...         A        A         A       4.0
#
#   refgen  hisp_ref hisp2  quarter  year  urban
# ...

# %%
df.describe()
# Out:
#            inc_rnkm      inc_rnk5      inc_rnk4      inc_rnk3      inc_rnk2  \
# count  68810.000000  68810.000000  68810.000000  68810.000000  68810.000000
# mean       0.509820      0.509919      0.509551      0.510002      0.509849
# std        0.289192      0.289088      0.288920      0.289007      0.289000
# min        0.000088      0.000088      0.000088      0.000088      0.000088
# 25%        0.259184      0.259430      0.259555      0.259938      0.259811
# 50%        0.514594      0.515088      0.513735      0.514715      0.514477
# 75%        0.761639      0.761249      0.760558      0.761416      0.761461
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            inc_rnk1      inc_rank         newid       age_ref          age2  \
# count  68810.000000  68810.000000  6.881000e+04  68810.000000  34480.000000
# mean       0.509733      0.510947  4.428078e+06     52.669423     52.600464
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        inc_rnkm  inc_rnk5  inc_rnk4  inc_rnk3  inc_rnk2  inc_rnk1  inc_rank  \
# 0      0.704287  0.706457  0.699513  0.705671  0.709034  0.707517  0.763599
# 1      0.704573  0.706744  0.699800  0.705958  0.709321  0.707804  0.763886
# 2      0.256737  0.272063  0.260261  0.263508  0.273057  0.266441  0.375717
# 3      0.256312  0.271638  0.259836  0.263083  0.272632  0.266016  0.375292
# 4      0.346813  0.360343  0.345145  0.350655  0.364780  0.354823  0.458908
# ...         ...       ...       ...       ...       ...       ...       ...
# 68805  0.239092  0.271931  0.374269  0.280364  0.282832  0.043820  0.121898
# 68806  0.877147  0.874315  0.873681  0.874214  0.878822  0.875734  0.905243
# 68807  0.877397  0.874565  0.873931  0.874464  0.879072  0.875984  0.905493
# 68808  0.895388  0.894263  0.894736  0.894646  0.897219  0.895381  0.922533
# 68809  0.894987  0.893863  0.894336  0.894245  0.896818  0.894980  0.922132
#
# ...

# %%
df.to_csv('interview_files.csv', index=False) # to R

# %%
df = pd.read_csv('updated_interview_file.csv')

# %%
df.head()
# Out:
#     expen  age_ref  sex_ref  white  black  american_indian  asian  other  \
# 0   48.36       27        1      1      0                0      0      0
# 1  124.30       27        1      1      0                0      0      0
# 2   40.12       53        2      1      0                0      0      0
# 3   28.50       56        1      1      0                0      0      0
# 4   37.77       56        1      1      0                0      0      0
#
#    multi_race  welf_reic  welf_not_reiv  fwagexm  year  quarter
# 0           0          0              1  89095.0  2017        1
# 1           0          0              1  89095.0  2017        1
# 2           0          0              1  26000.0  2017        1
# 3           0          0              1  35000.0  2017        1
# 4           0          0              1  35000.0  2017        1

# %%
sns.displot(df['expen'], kde=True, height=5, aspect=2)

# %%
df['expen'].sort_values(ascending=True).tail(25)
# Out:
# 28713    2017.54000
# 1685     2049.69001
# 37829    2091.99000
# 13030    2099.30329
# 16039    2253.67001
# 15977    2267.37458
# 16783    2276.44000
# 8448     2323.98001
# 34527    2415.37452
# 21951    2458.01081
# 37450    2469.60001
# 37616    2507.14513
# 12724    2525.86001
# 29133    2576.00001
# 39865    2732.16000
# 1417     2930.86000
# 37758    3026.54815
# 14682    3331.91374
# 19409    3499.56000
# 5127     3617.82000
# 9126     4033.86000
# 30038    4235.42000
# 33667    4249.83000
# 2116     4463.39159
# 27022    5061.69000
# Name: expen, dtype: float64

# %%
df[df['expen'] > 2000].sort_values('expen')
# Out:
#             expen  age_ref  sex_ref  white  black  american_indian  asian  \
# 17615  2011.32345       45        2      1      0                0      0
# 28713  2017.54000       58        2      1      0                0      0
# 1685   2049.69001       52        2      1      0                0      0
# 37829  2091.99000       63        2      1      0                0      0
# 13030  2099.30329       39        1      1      0                0      0
# 16039  2253.67001       63        1      1      0                0      0
# 15977  2267.37458       53        1      1      0                0      0
# 16783  2276.44000       45        2      0      0                0      1
# 8448   2323.98001       47        2      1      0                0      0
# 34527  2415.37452       54        1      1      0                0      0
# 21951  2458.01081       60        2      1      0                0      0
# 37450  2469.60001       39        2      0      0                0      1
# ...

# %%
df['welf_reic'].value_counts()
# Out:
# welf_reic
# 0    40328
# 1      192
# Name: count, dtype: int64

# %%
df_welf = df[df['welf_reic']== 1]
df_welf.head()
# Out:
#          expen  age_ref  sex_ref  white  black  american_indian  asian  other  \
# 264   59.27000       32        2      1      0                0      0      0
# 265  591.95000       32        2      1      0                0      0      0
# 305  210.03000       37        2      1      0                0      0      0
# 306  131.15000       37        2      1      0                0      0      0
# 653  319.78001       57        2      0      1                0      0      0
#
#      multi_race  welf_reic  welf_not_reiv  fwagexm  year  quarter
# 264           0          1              0  25188.0  2017        1
# 265           0          1              0  23431.0  2017        1
# 305           0          1              0  25200.0  2017        1
# 306           0          1              0  25200.0  2017        1
# 653           0          1              0   1570.0  2017        1

# %%
len(df_welf['expen'])
# Out:
# 192

# %%
df[['white', 'black', 'american_indian', 'asian', 'other', 'multi_race']].value_counts()
# Out:
# white  black  american_indian  asian  other  multi_race
# 1      0      0                0      0      0             32420
# 0      1      0                0      0      0              3957
#        0      0                1      0      0              2936
#                                0      0      1               829
#               1                0      0      0               222
#               0                0      1      0               156
# Name: count, dtype: int64

# %%
df['sex_ref'].value_counts()
# Out:
# sex_ref
# 2    21390
# 1    19130
# Name: count, dtype: int64

# %%
df_welf[['white', 'black', 'american_indian', 'asian', 'other', 'multi_race']].value_counts()
# Out:
# white  black  american_indian  asian  other  multi_race
# 1      0      0                0      0      0             135
# 0      1      0                0      0      0              36
#        0      0                1      0      0              12
#                                0      0      1               8
#               1                0      0      0               1
# Name: count, dtype: int64

# %%
df_welf[df_welf['sex_ref'] == 1][['white', 'black', 'american_indian', 'asian', 'other', 'multi_race']].value_counts()
# Out:
# white  black  american_indian  asian  other  multi_race
# 1      0      0                0      0      0             34
# 0      0      0                1      0      0              7
#        1      0                0      0      0              6
# Name: count, dtype: int64

# %%
df_welf[df_welf['sex_ref'] == 2][['white', 'black', 'american_indian', 'asian', 'other', 'multi_race']].value_counts()
# Out:
# white  black  american_indian  asian  other  multi_race
# 1      0      0                0      0      0             101
# 0      1      0                0      0      0              30
#        0      0                0      0      1               8
#                                1      0      0               5
#               1                0      0      0               1
# Name: count, dtype: int64

# %%
df_welf['sex_ref'].value_counts() # WOW!
# Out:
# sex_ref
# 2    145
# 1     47
# Name: count, dtype: int64

# %%
print('Men on Welfare Expenditure Mean:', df_welf[df_welf['sex_ref'] == 1]['expen'].mean())
print('Women on Welfare Expenditure Mean:', df_welf[df_welf['sex_ref'] == 2]['expen'].mean())
# Out:
# Men on Welfare Expenditure Mean: 271.6715478723404
# Women on Welfare Expenditure Mean: 174.660854

# %%
print('Difference:', (df_welf[df_welf['sex_ref'] == 1]['expen'].mean()) - (df_welf[df_welf['sex_ref'] == 2]['expen'].mean()))
# Out:
# Difference: 97.0106938723404

# %%
(df[df['sex_ref'] == 1]['expen'].mean()) - (df[df['sex_ref'] == 2]['expen'].mean())
# Out:
# 0.7168002259357706

# %%
print('Men Expenditure Mean:', df[df['sex_ref'] == 1]['expen'].mean())
print('Women Expenditure Mean:', df[df['sex_ref'] == 2]['expen'].mean())
# Out:
# Men Expenditure Mean: 242.6757677313121
# Women Expenditure Mean: 241.95896750537634

# %%
print('No Welfare', df['expen'].mean())
print('With Welfare', df_welf['expen'].mean())
print('Difference', df['expen'].mean() - df_welf['expen'].mean())
# Out:
# No Welfare 242.29737787857846
# With Welfare 198.40826343749998
# Difference 43.889114441078476

# %%
df['during_post_covid_dummy'] = (((df['year'].isin([2020]) & df['quarter'].between(2, 4)) | 
    (df['year'].isin([2021, 2022]))).astype(int))

df[df['during_post_covid_dummy'] == 1]
# Out:
#            expen  age_ref  sex_ref  white  black  american_indian  asian  \
# 22402  150.36000       56        1      1      0                0      0
# 22403   73.15000       40        2      0      0                0      0
# 22404   93.88000       40        2      0      0                0      0
# 22405  175.12000       45        1      1      0                0      0
# 22406  129.12000       45        1      1      0                0      0
# ...          ...      ...      ...    ...    ...              ...    ...
# 40515   91.51000       61        1      1      0                0      0
# 40516  589.67375       41        2      1      0                0      0
# 40517  654.62839       41        2      1      0                0      0
# 40518  602.46377       51        1      1      0                0      0
# 40519  852.84996       51        1      1      0                0      0
#
#        other  multi_race  welf_reic  welf_not_reiv   fwagexm  year  quarter  \
# ...

# %%
df_welf['during_post_covid_dummy'] = (((df_welf['year'].isin([2020]) & df_welf['quarter'].between(2, 4)) | 
    (df_welf['year'].isin([2021, 2022]))).astype(int))

df_welf[df_welf['during_post_covid_dummy'] == 1]
# Out:
# /tmp/ipykernel_13536/3625937765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_welf['during_post_covid_dummy'] = (((df_welf['year'].isin([2020]) & df_welf['quarter'].between(2, 4)) |
#            expen  age_ref  sex_ref  white  black  american_indian  asian  \
# 23083   42.40000       44        1      1      0                0      0
# 23084  226.00002       44        1      1      0                0      0
# 23238  195.92000       29        2      0      0                0      1
# 23239  134.57000       29        2      0      0                0      1
# 23240  166.51998       30        2      1      0                0      0
# ...          ...      ...      ...    ...    ...              ...    ...
# ...

# %%
df.loc[df['sex_ref']==1, 'male']=1
df.loc[df['sex_ref']==2, 'male']=0

df.head(5)
# Out:
#     expen  age_ref  sex_ref  white  black  american_indian  asian  other  \
# 0   48.36       27        1      1      0                0      0      0
# 1  124.30       27        1      1      0                0      0      0
# 2   40.12       53        2      1      0                0      0      0
# 3   28.50       56        1      1      0                0      0      0
# 4   37.77       56        1      1      0                0      0      0
#
#    multi_race  welf_reic  welf_not_reiv  fwagexm  year  quarter  \
# 0           0          0              1  89095.0  2017        1
# 1           0          0              1  89095.0  2017        1
# 2           0          0              1  26000.0  2017        1
# 3           0          0              1  35000.0  2017        1
# 4           0          0              1  35000.0  2017        1
#
#    during_post_covid_dummy  male
# 0                        0   1.0
# 1                        0   1.0
# 2                        0   0.0
# ...

# %%
df_welf.loc[df_welf['sex_ref']==1, 'male']=1
df_welf.loc[df['sex_ref']==2, 'male']=0

df_welf.head(5)
# Out:
# /tmp/ipykernel_13536/3404240722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_welf.loc[df_welf['sex_ref']==1, 'male']=1
#          expen  age_ref  sex_ref  white  black  american_indian  asian  other  \
# 264   59.27000       32        2      1      0                0      0      0
# 265  591.95000       32        2      1      0                0      0      0
# 305  210.03000       37        2      1      0                0      0      0
# 306  131.15000       37        2      1      0                0      0      0
# 653  319.78001       57        2      0      1                0      0      0
#
#      multi_race  welf_reic  welf_not_reiv  fwagexm  year  quarter  \
# ...

# %%
reg = smf.ols(formula = "expen ~ age_ref + male + white + black + american_indian + asian + other + multi_race + during_post_covid_dummy + welf_reic + fwagexm", data=df)
results = reg.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  expen   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     586.3
# Date:                Tue, 09 Apr 2024   Prob (F-statistic):               0.00
# Time:                        10:58:58   Log-Likelihood:            -2.7341e+05
# No. Observations:               40520   AIC:                         5.468e+05
# Df Residuals:                   40509   BIC:                         5.469e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  97.6748      4.688     20.836      0.000      88.487     106.863
# ...

# %%
reg1 = smf.ols(formula = "expen ~ age_ref + male + white + black + american_indian + asian + other + multi_race + during_post_covid_dummy + fwagexm", data=df_welf)
results1 = reg1.fit()
print(results1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  expen   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     3.547
# Date:                Tue, 09 Apr 2024   Prob (F-statistic):           0.000763
# Time:                        10:58:58   Log-Likelihood:                -1283.5
# No. Observations:                 192   AIC:                             2585.
# Df Residuals:                     183   BIC:                             2614.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  93.2776     57.407      1.625      0.106     -19.988     206.543
# ...

# %%
y = df['expen']

X = df[['age_ref', 'male', 'white', 'black', 'american_indian', 'asian', 'other', 'multi_race', 'during_post_covid_dummy', 'welf_reic', 'fwagexm']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 1.32538722e+00, -1.28029446e+01,  6.60207881e-01, -5.90315058e+01,
#         2.73005391e+00, -1.26982993e+01,  6.19423144e+01,  6.39722888e+00,
#         8.42734711e+00,  2.81618744e+01,  8.49390521e-04])

# %%
coeff_df = pd.DataFrame(lr.coef_, X.columns, columns=['Coef'])
print(coeff_df)
# Out:
#                               Coef
# age_ref                   1.325387
# male                    -12.802945
# white                     0.660208
# black                   -59.031506
# american_indian           2.730054
# asian                   -12.698299
# other                    61.942314
# multi_race                6.397229
# during_post_covid_dummy   8.427347
# welf_reic                28.161874
# fwagexm                   0.000849

# %%
predict = lr.predict(X_test)

plt.scatter(y_test, predict)

# %%
sns.histplot(predict, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predict))
print('MSE:', metrics.mean_squared_error(y_test, predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predict)))
# Out:
# MAE: 142.02505923503966
# MSE: 45168.8426075632
# RMSE: 212.5296275994554
